# %%
s ="ineuron"

# %%
type(s)
# Out:
# str

# %%
s[0]
# Out:
# 'i'

# %%
s[5]
# Out:
# 'o'

# %%
s[-1]
# Out:
# 'n'

# %%
s1='Robin'

# %%
s1[0]
# Out:
# 'R'

# %%
s1[-1]
# Out:
# 'n'

# %%
s1[-2]
# Out:
# 'i'

# %%
'this is my very first programming class'
# Out:
# 'this is my very first programming class'

# %%
'this is my very first programming class's'
# Out:
#   File "<ipython-input-12-3bdf2a15bbf7>", line 1
#     'this is my very first programming class's'
#                                               ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
"this is my very first programming class's"
# Out:
# "this is my very first programming class's"

# %%
s2 = "this is my very first programming class's"

# %%
s2
# Out:
# "this is my very first programming class's"

# %%
s2[8]
# Out:
# 'm'

# %%
s2
# Out:
# "this is my very first programming class's"

# %%
s[2:5]
# Out:
# 'eur'

# %%
s2[1:5]
# Out:
# 'his '

# %%
s2[6:30]
# Out:
# 's my very first programm'

# %%
s2
# Out:
# "this is my very first programming class's"

# %%
s2[6:30:2]
# Out:
# 'sm eyfrtporm'

# %%
s= "sudhanshu"

# %%
s[0:9:1]
# Out:
# 'sudhanshu'

# %%
s[0:9:1]
# Out:
# 'sudhanshu'

# %%
s[0:8:-1]
# Out:
# ''

# %%
s[8:0:-1]
# Out:
# 'uhsnahdu'

# %%
s[8:0:-2]
# Out:
# 'usad'

# %%
s
# Out:
# 'sudhanshu'

# %%
s[:-3]
# Out:
# 'sudhan'

# %%
s[-2]
# Out:
# 'h'

# %%
s
# Out:
# 'sudhanshu'

# %%
s[-2]
# Out:
# 'h'

# %%
s[-2:]
# Out:
# 'hu'

# %%
s[::1]
# Out:
# 'sudhanshu'

# %%
s[0:50:1]
# Out:
# 'sudhanshu'

# %%
s[::-1]
# Out:
# 'uhsnahdus'

# %%
s2
# Out:
# "this is my very first programming class's"

# %%
s2[0::-1]
# Out:
# 't'

# %%
s2
# Out:
# "this is my very first programming class's"

# %%
s2[::-1]
# Out:
# "s'ssalc gnimmargorp tsrif yrev ym si siht"

# %%
s
# Out:
# 'sudhanshu'

# %%
s[8:0:-1]
# Out:
# 'uhsnahdu'

# %%
s
# Out:
# 'sudhanshu'

# %%
s3 = 'ineuron'

# %%
s3[::-1]
# Out:
# 'norueni'

# %%
s3[-2:-7:1]
# Out:
# ''

# %%
s3[-7:-2:1]
# Out:
# 'ineur'

# %%
s
# Out:
# 'sudhanshu'

# %%
s[50:1]
# Out:
# ''

# %%
s
# Out:
# 'sudhanshu'

# %%
s[:-1:-1]
# Out:
# ''

# %%
s[0]
# Out:
# 's'

# %%
s
# Out:
# 'sudhanshu'

# %%
s+1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-61-2a618fcb9031> in <cell line: 1>()
# ----> 1 s+1
#
# TypeError: can only concatenate str (not "int") to str

# %%
s+'1'
# Out:
# 'sudhanshu1'

# %%
s+"1"
# Out:
# 'sudhanshu1'

# %%
s+str(1)
# Out:
# 'sudhanshu1'

# %%
s
# Out:
# 'sudhanshu'

# %%
len(s)
# Out:
# 9

# %%
s*2
# Out:
# 'sudhanshusudhanshu'

# %%
s*4
# Out:
# 'sudhanshusudhanshusudhanshusudhanshu'

# %%
s
# Out:
# 'sudhanshu'

# %%
s.capitalize
# Out:
# <function str.capitalize()>

# %%
s
# Out:
# 'sudhanshu'

# %%
s.count(s)
# Out:
# 1

# %%
s
# Out:
# 'sudhanshu'

# %%
s.count(u)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-74-c5c20d14c3b1> in <cell line: 1>()
# ----> 1 s.count(u)
#
# NameError: name 'u' is not defined

# %%
s.count('s')
# Out:
# 2

# %%
s.count('su')
# Out:
# 1

# %%
s.count('sum')
# Out:
# 0

# %%
s.split('u')
# Out:
# ['s', 'dhansh', '']

# %%
s
# Out:
# 'sudhanshu'

# %%
type(s.split('u'))
# Out:
# list

# %%
sw.split(' ')
# Out:
# ['I',
#  'hope',
#  'this',
#  'email',
#  'finds',
#  'you',
#  'well.',
#  'I',
#  'am',
#  'writing',
#  'to',
#  'bring',
#  'to',
#  'your',
#  'attention',
#  'a',
#  'persistent',
#  'issue',
#  '']

# %%
sw="""I hope this email finds you well. I am writing to bring to your attention a persistent issue I have been facing with my State Bank of India (SBI) debit card, which is preventing me from using it for eCommerce transactions.

Despite having enabled my debit card for eCommerce transactions through various methods, including IVR, YONO, and Internet banking, I am constantly encountering difficulties when trying to make online purchases. This issue has persisted for a considerable amount of time, and I would like to request your assistance in resolving it.

Here are some additional details that may help in addressing the issue:

- My SBI account number: [20319424045]
- Registered mobile number associated with the account: [9466451807]
- Debit card number: [6522940470369250]
- Date when I enabled eCommerce transactions: [31/08/2023]
- Error messages received during eCommerce transactions: [Please ensure your card is enabled for online transactions.]

I have taken the following steps to ensure that my debit card is enabled for eCommerce transactions:

1. I used the IVR service to enable eCommerce transactions by following the automated instructions.

2. I accessed the YONO app and enabled the debit card for online transactions as per the app's guidance.

3. I also logged into my SBI Internet banking account and made sure that the eCommerce option was activated.

Despite these efforts, I continue to face difficulties while attempting to use my debit card for online purchases. This issue has become increasingly inconvenient, especially in today's digital age when online transactions are so common.

I kindly request that you investigate this matter urgently and provide a solution to enable me to use my SBI debit card for e-commerce transactions seamlessly. Having a functional debit card for online purchases is vital for my day-to-day activities and financial transactions.

If there are any specific steps I need to follow or additional information you require to resolve this issue, please do not hesitate to inform me. Your prompt attention to this matter and a speedy resolution would be greatly appreciated.

Thank you for your assistance, and I look forward to your response.

Sincerely,

[Robin Raj]
[9466451807]

"""

# %%
sw.count('I')
# Out:
# 24

# %%
sw
# Out:
# "I hope this email finds you well. I am writing to bring to your attention a persistent issue I have been facing with my State Bank of India (SBI) debit card, which is preventing me from using it for eCommerce transactions.\n\nDespite having enabled my debit card for eCommerce transactions through various methods, including IVR, YONO, and Internet banking, I am constantly encountering difficulties when trying to make online purchases. This issue has persisted for a considerable amount of time, and I would like to request your assistance in resolving it.\n\nHere are some additional details that may help in addressing the issue:\n\n- My SBI account number: [20319424045]\n- Registered mobile number associated with the account: [9466451807]\n- Debit card number: [6522940470369250]\n- Date when I enabled eCommerce transactions: [31/08/2023]\n- Error messages received during eCommerce transactions: [Please ensure your card is enabled for online transactions.]\n\nI have taken the following 
# ...

# %%
sw.capitalize(sw)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-95-b7dd0ab04a32> in <cell line: 1>()
# ----> 1 sw.capitalize(sw)
#
# TypeError: str.capitalize() takes no arguments (1 given)

# %%
sw.upper()
# Out:
# "I HOPE THIS EMAIL FINDS YOU WELL. I AM WRITING TO BRING TO YOUR ATTENTION A PERSISTENT ISSUE I HAVE BEEN FACING WITH MY STATE BANK OF INDIA (SBI) DEBIT CARD, WHICH IS PREVENTING ME FROM USING IT FOR ECOMMERCE TRANSACTIONS.\n\nDESPITE HAVING ENABLED MY DEBIT CARD FOR ECOMMERCE TRANSACTIONS THROUGH VARIOUS METHODS, INCLUDING IVR, YONO, AND INTERNET BANKING, I AM CONSTANTLY ENCOUNTERING DIFFICULTIES WHEN TRYING TO MAKE ONLINE PURCHASES. THIS ISSUE HAS PERSISTED FOR A CONSIDERABLE AMOUNT OF TIME, AND I WOULD LIKE TO REQUEST YOUR ASSISTANCE IN RESOLVING IT.\n\nHERE ARE SOME ADDITIONAL DETAILS THAT MAY HELP IN ADDRESSING THE ISSUE:\n\n- MY SBI ACCOUNT NUMBER: [20319424045]\n- REGISTERED MOBILE NUMBER ASSOCIATED WITH THE ACCOUNT: [9466451807]\n- DEBIT CARD NUMBER: [6522940470369250]\n- DATE WHEN I ENABLED ECOMMERCE TRANSACTIONS: [31/08/2023]\n- ERROR MESSAGES RECEIVED DURING ECOMMERCE TRANSACTIONS: [PLEASE ENSURE YOUR CARD IS ENABLED FOR ONLINE TRANSACTIONS.]\n\nI HAVE TAKEN THE FOLLOWING 
# ...

# %%
sw.lower()
# Out:
# "i hope this email finds you well. i am writing to bring to your attention a persistent issue i have been facing with my state bank of india (sbi) debit card, which is preventing me from using it for ecommerce transactions.\n\ndespite having enabled my debit card for ecommerce transactions through various methods, including ivr, yono, and internet banking, i am constantly encountering difficulties when trying to make online purchases. this issue has persisted for a considerable amount of time, and i would like to request your assistance in resolving it.\n\nhere are some additional details that may help in addressing the issue:\n\n- my sbi account number: [20319424045]\n- registered mobile number associated with the account: [9466451807]\n- debit card number: [6522940470369250]\n- date when i enabled ecommerce transactions: [31/08/2023]\n- error messages received during ecommerce transactions: [please ensure your card is enabled for online transactions.]\n\ni have taken the following 
# ...

# %%
sw
# Out:
# "I hope this email finds you well. I am writing to bring to your attention a persistent issue I have been facing with my State Bank of India (SBI) debit card, which is preventing me from using it for eCommerce transactions.\n\nDespite having enabled my debit card for eCommerce transactions through various methods, including IVR, YONO, and Internet banking, I am constantly encountering difficulties when trying to make online purchases. This issue has persisted for a considerable amount of time, and I would like to request your assistance in resolving it.\n\nHere are some additional details that may help in addressing the issue:\n\n- My SBI account number: [20319424045]\n- Registered mobile number associated with the account: [9466451807]\n- Debit card number: [6522940470369250]\n- Date when I enabled eCommerce transactions: [31/08/2023]\n- Error messages received during eCommerce transactions: [Please ensure your card is enabled for online transactions.]\n\nI have taken the following 
# ...

# %%
sw=sw.upper()

# %%
sw
# Out:
# "I HOPE THIS EMAIL FINDS YOU WELL. I AM WRITING TO BRING TO YOUR ATTENTION A PERSISTENT ISSUE I HAVE BEEN FACING WITH MY STATE BANK OF INDIA (SBI) DEBIT CARD, WHICH IS PREVENTING ME FROM USING IT FOR ECOMMERCE TRANSACTIONS.\n\nDESPITE HAVING ENABLED MY DEBIT CARD FOR ECOMMERCE TRANSACTIONS THROUGH VARIOUS METHODS, INCLUDING IVR, YONO, AND INTERNET BANKING, I AM CONSTANTLY ENCOUNTERING DIFFICULTIES WHEN TRYING TO MAKE ONLINE PURCHASES. THIS ISSUE HAS PERSISTED FOR A CONSIDERABLE AMOUNT OF TIME, AND I WOULD LIKE TO REQUEST YOUR ASSISTANCE IN RESOLVING IT.\n\nHERE ARE SOME ADDITIONAL DETAILS THAT MAY HELP IN ADDRESSING THE ISSUE:\n\n- MY SBI ACCOUNT NUMBER: [20319424045]\n- REGISTERED MOBILE NUMBER ASSOCIATED WITH THE ACCOUNT: [9466451807]\n- DEBIT CARD NUMBER: [6522940470369250]\n- DATE WHEN I ENABLED ECOMMERCE TRANSACTIONS: [31/08/2023]\n- ERROR MESSAGES RECEIVED DURING ECOMMERCE TRANSACTIONS: [PLEASE ENSURE YOUR CARD IS ENABLED FOR ONLINE TRANSACTIONS.]\n\nI HAVE TAKEN THE FOLLOWING 
# ...

# %%
s = "Robin"

# %%
s.title()
# Out:
# 'Robin'

# %%
s
# Out:
# 'Robin'

# %%
s='robin'

# %%
s.title()
# Out:
# 'Robin'

# %%
s='robin kumar'

# %%
s.title()
# Out:
# 'Robin Kumar'

# %%
s.capitalize()
# Out:
# 'Robin kumar'

# %%
s
# Out:
# 'robin kumar'

# %%
s.swapcase()
# Out:
# 'ROBIN KUMAR'

# %%
''.joinreverse(s)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-120-023c64f320c5> in <cell line: 1>()
# ----> 1 ''.joinreverse(s)
#
# AttributeError: 'str' object has no attribute 'joinreverse'

# %%
s
# Out:
# 'robin kumar'

# %%
s.strip()
# Out:
# 'robin kumar'

# %%
s = "    ro      bi       "

# %%
s.strip()
# Out:
# 'ro      bi'

# %%
s
# Out:
# '    ro      bi       '

# %%
s.lstrip()
# Out:
# 'ro      bi       '

# %%
s.rstrip()
# Out:
# '    ro      bi'

# %%
s
# Out:
# '    ro      bi       '

# %%
"a" .join("robin")
# Out:
# 'raoabaian'

# %%
s
# Out:
# '    ro      bi       '

# %%
s= "robi"

# %%
s.center(20,'a')
# Out:
# 'aaaaaaaarobiaaaaaaaa'

# %%
s.isalnum
# Out:
# <function str.isalnum()>

# %%
s
# Out:
# 'robi'

# %%
s.islower()
# Out:
# True

# %%
s.isupper()
# Out:
# False

# %%
s.isnumeric()
# Out:
# False

# %%
s.isalpha()
# Out:
# True

# %%
s
# Out:
# 'robi'

# %%
s.isspace()
# Out:
# False

# %%
s.isprintable()
# Out:
# True

# %%
s.isdigit()
# Out:
# False

# %%
s1="546456"

# %%
s1.isdigit()
# Out:
# True

# %%
s2 = "45sgs5sggs544"

# %%
s2.isdigit()
# Out:
# False

# %%
s2.isalpha()
# Out:
# False

# %%
s2
# Out:
# '45sgs5sggs544'

# %%
s2.isalpha()
# Out:
# False

# %%
s2.isalphanumeric()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-153-82401e9e65cd> in <cell line: 1>()
# ----> 1 s2.isalphanumeric()
#
# AttributeError: 'str' object has no attribute 'isalphanumeric'

# %%
s.startwith(i)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-154-01f8d9664385> in <cell line: 1>()
# ----> 1 s.startwith(i)
#
# AttributeError: 'str' object has no attribute 'startwith'

# %%
s
# Out:
# 'robi'

# %%
s2
# Out:
# '45sgs5sggs544'

# %%
s3 = "Robin"

# %%
s3.startswith('i')
# Out:
# False

# %%
s3.startswith('r')
# Out:
# False

# %%
s3.startswith('R')
# Out:
# True

# %%
  s3.endswith('i')
# Out:
# False

# %%
s3.endswith('n')
# Out:
# True

# %%
s
# Out:
# 'robi'

# %%
s.isdigit()
# Out:
# False

# %%
s.startswith("")
# Out:
# True

# %%
s
# Out:
# 'robi'

# %%
s.isascii()
# Out:
# True

# %%
s
# Out:
# 'robi'

# %%
s.isalnum()
# Out:
# True

# %%
s.center(20,'@')
# Out:
# '@@@@@@@@robi@@@@@@@@'

# %%
s
# Out:
# 'robi'

# %%
r = 'robi'

# %%
reversed(r)

# %%
# Define your string
my_string = "HELLO"

# Use slicing to reverse the string
reversed_string = my_string[::-1]

# Print the reversed string
print(reversed_string)
# Out:
# OLLEH

# %%
s
# Out:
# 'robi'

# %%
s  = "dgs\tvsd\tsgvs"

# %%
s.expandtabs(4)
# Out:
# 'dgs vsd sgvs'

# %%
s = "this is My First Python programming class and i am learNING python string and its function"
1 . Try to extract data from index one to index 300 with a jump of 3
2. Try to reverse a string without using reverse function
3. Try to split a string after conversion of entire string in uppercase
4. try to convert the whole string into lower case
5 . Try to capitalize the whole string
6 . Write a diference between isalnum() and isalpha()
7. Try to give an example of expand tab
8 . Give an example of strip , lstrip and rstrip
9.  Replace a string charecter by another charector by taking your own example
"sudhanshu"
10 . Try  to give a defination of string center function with and exmple
11 . Write your own definition of compiler and interpretor without copy paste form internet in your own language
12 . Python is a interpreted of compiled language give a clear ans with your understanding
13 . Try to write a usecase of python with your understanding .
# Out:
#   File "<ipython-input-183-66dfaef31233>", line 2
#     1 . Try to extract data from index one to index 300 with a jump of 3
#             ^
# SyntaxError: invalid syntax

# %%
s = "this is My First Python programming class and i am learNING python string and its function"

# %%
s
# Out:
# 'this is My First Python programming class and i am learNING python string and its function'

# %%
print(s)
# Out:
# this is My First Python programming class and i am learNING python string and its function

# %%
#s = "this is My First Python programming class and i am learNING python string and its function"

# %%
#1 . Try to extract data from index one to index 300 with a jump of 3

# %%
s = "this is My First Python programming class and i am learNING python string and its function"

# %%
s[1:300:3]
# Out:
# 'h   r tnrrmglsnimeNGyosi dtfco'

# %%
print(s)
# Out:
# this is My First Python programming class and i am learNING python string and its function

# %%
s
# Out:
# 'this is My First Python programming class and i am learNING python string and its function'

# %%
s[::-1]
# Out:
# 'noitcnuf sti dna gnirts nohtyp GNINrael ma i dna ssalc gnimmargorp nohtyP tsriF yM si siht'

# %%
# 2. Try to reverse a string without using reverse function

# %%
s
# Out:
# 'ROBIN RAJ'

# %%
s[::-1]
# Out:
# 'JAR NIBOR'

# %%
#3. Try to split a string after conversion of entire string in uppercase

# %%
s
# Out:
# 'this is My First Python programming class and i am learNING python string and its function'

# %%
s.upper()
# Out:
# 'THIS IS MY FIRST PYTHON PROGRAMMING CLASS AND I AM LEARNING PYTHON STRING AND ITS FUNCTION'

# %%
s.split()
# Out:
# ['this',
#  'is',
#  'My',
#  'First',
#  'Python',
#  'programming',
#  'class',
#  'and',
#  'i',
#  'am',
#  'learNING',
#  'python',
#  'string',
#  'and',
#  'its',
#  'function']

# %%
#4. try to convert the whole string into lower case

# %%
s
# Out:
# 'this is My First Python programming class and i am learNING python string and its function'

# %%
s.lower()
# Out:
# 'this is my first python programming class and i am learning python string and its function'

# %%
#5. Try to capitalize the whole string

# %%
s
# Out:
# 'this is My First Python programming class and i am learNING python string and its function'

# %%
s.capitalize()
# Out:
# 'This is my first python programming class and i am learning python string and its function'

# %%
#6 . Write a diference between isalnum() and isalpha()

# %%
# isalnum() is a string function, which will return boolean value as per alphabets or numeric value; While isalpha(),a string function, which will return boolean value as per passed string, If string is only alphabet or not.

# %%
# 7. Try to give an example of expand tab

# %%
"""s = "Robin\tRaj"
s.expandtabs(4)"""
# Out:
# 's = "Robin\tRaj"\ns.expandtabs(4)'

# %%
# 8 . Give an example of strip , lstrip and rstrip

# %%
s = '       robin  raj gupta'

# %%
s.lstrip()
# Out:
# 'robin  raj gupta'

# %%
s1 = '    Robin Raj      '

# %%
s.rstrip()
# Out:
#   File "<ipython-input-60-e3ddba4f2e28>", line 1
#     s.rstrip()  """
#                 ^
# SyntaxError: incomplete input

# %%
# Out:
#   File "<ipython-input-59-e4615a684824>", line 1
#     """
#     ^
# SyntaxError: incomplete input

# %%
# 9.  Replace a string charecter by another charector by taking your own example "sudhanshu"

# %%
# 10 . Try  to give a defination of string center function with and exmple

# %%
s = 'ROBIN RAJ'

# %%
s.center(30,"-")
# Out:
# '----------ROBIN RAJ-----------'

# %%
# 11 . Write your own definition of compiler and interpretor without copy paste form internet in your own language

# %%
""" Compiler is a translator, which translates source code into object code at compile time, While Interpreter is the translator which translates source code into object code at run time"""
# Out:
# ' Compiler is a translator, which translates source code into object code at compile time, While Interpreter is the translator which translates source code into object code at run time'

# %%
# 12 . Python is a interpreted of compiled language give a clear ans with your understanding

# %%
# It is compiled languag,
# Out:
# ' xyz  '

# %%
# 13 . Try to write a usecase of python with your understanding .
