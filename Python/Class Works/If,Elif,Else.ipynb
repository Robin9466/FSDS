# %%
a = 10
if a == 11 :
  print("This is my first condition")

# %%
a = 10
if a>5 :
  pass

# %%
a = 10
if a<8 :
  print("print this if condition is true")

# %%
a = 10
if a !=11:
  print("my condition is false")
else:
  print("print this")
# Out:
# my condition is false

# %%
a = 10
if a ==11:
  print("my condition is false")
else:
  print("print this")
# Out:
# print this

# %%
a = 10
if a == 12:
  print("Here we are trying to compare 10 with 12")
elif a == 11:
  print("we are trying to compare 10 with 11")
else:
  print("if all the blocks will fail then do this")
# Out:
# if all the blocks will fail then do this

# %%
a = 10
if a == 12:
  print("Here we are trying to compare 10 with 12")
elif a == 10:
  print("we are trying to compare 10 with 11")
else:
  print("if all the blocks will fail then do this")
# Out:
# we are trying to compare 10 with 11

# %%
price = 500
if price>500:
  print(" May b i won't be able to buy a jacket")
elif price<=500:
  print("Will be able to buy jacket")
# Out:
# Will be able to buy jacket

# %%
price = 500
if price>500:
  print(" May b i won't be able to buy a jacket")
elif price<500:
  print("Will be able to buy jacket")
else price == 500 :
  print("I don't know")

# %%
price = 500
if price>500 :
  print(" May b i won't be able to buy a jacket")
elif price<500 :
  print("Will be able to buy jacket")
elif price == 500 :
  print("For sure, I will be able to buy")
else :
  print("I don't know")

# %%
l = [1,2,3,4,5,6,]
if 60 in l :
  print("try to perform a task")
else :
  print("Do not perform this task")

# %%
l

# %%
if 10 in l :
  print("try to do a additoon")
elif 2 in l :
  print("Try to do sub")
elif 3 in l :
  print("try to do mul")
if 4 in l :
  print("this is new statement")

# %%
a = 400

# %%
b = int(input())
# Out:
# 35

# %%
b
# Out:
# 35

# %%
type(b)
# Out:
# int

# %%
price = int(input())
if price <500 :
    print("I will be able to buy something")
    if price < 400 :
        print("I will be able to buy a jacket")
    elif price < 300 :
        print("I will be able to buy a shirt")
        if price < 200 :
          print("I would like to buy somethng")
    else :
          print("I will not be able to buy anything")
else :
      print("I will not be able to buy anything with this price tag")
      if price >500 :
        print("lets try something else")
# Out:
# 600
# I will not be able to buy anything with this price tag
# lets try something else

# %%
m = 600
if m > 600 :
  print("GRE")
  if m < 600 :
    print("NoGRE")
    if m < 500:
      print("TOFEL")
      if m < 400 :
        print("Try Something else")

# %% [markdown]
# ---
#
# *italicized text*![image.png](data:image/png;base64,...)

# %%
val = float(input("Enter a floating point number"))
if val >= 0 :
  if val == 0 :
    print("Entered value is zero")
  else :
    print("Enetred no is positive no")
else :
    print("Enetred no is negative no")
# Out:
# Enter a floating point number45
# Enetred no is positive no

# %%
a = 10
if a < 10 or a > 10 :
  print("Try to do something")

# %%
a = "sudh"
if a == "sudh"  or a == "Sudh" :
  print("This is sudh")
# Out:
# This is sudh

# %%
a = 10
b = 11
c = 12
d = 13
if a == 9 or b == 11 and c == 12 and d == 13 :
  print("Lets do something")
# Out:
# Lets do something

# %%
d = {'key1': 'value','key2':'sudh','key3': 'iNeuron'}
if d['key1']==  "value" and d['key2'] == 'sudh' and d['key3'] == 'iNeuron' :
  print("All the values are verified")
  print(d.values())
else :
  print("All the values are not verified")
# Out:
# All the values are verified
# dict_values(['value', 'sudh', 'iNeuron'])

# %%
l = [4,65465,6546,56,6,6,54,6,'dfhdf',6564,4]

# %%
l[0]
# Out:
# 4

# %%
l[1]
# Out:
# 65465

# %%
l[1:5]
# Out:
# [65465, 6546, 56, 6]

# %%
for i in l :
  print(i)
# Out:
# 4
# 65465
# 6546
# 56
# 6
# 6
# 54
# 6
# dfhdf
# 6564
# 4

# %%
"""m = 489
if m > 600 :
  print("GRE")
if m < 600 :
  print("NoGRE")
  if m < 500 :
    print("TOFEL")
    if m < 400 :
      print("Try something else")"""
# Out:
# 'm = 489\nif m > 600 :\n  print("GRE")\nif m < 600 :\n  print("NoGRE")\n  if m < 500 :\n    print("TOFEL")\n    if m < 400 :\n      print("Try something else")'

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
m = int(input())

if m > 600:
    print("GRE")
elif m < 600 and m >= 500:
    print("NO GRE")
elif m < 500 and m >= 400:
    print("TOEFL")
else:
    print("Try something else")
# Out:
# 489
# TOEFL
