# %%
from flask import Flask , render_template, jsonify
import requests
from bs4 import BeautifulSoup as bs 
from urllib.request import urlopen as urReq

# %%
flipkart_url = "https://www.flipkart.com/search?q="+"oneplus"

# %%
flipkart_url
# Out:
# 'https://www.flipkart.com/search?q=oneplus'

# %%
response = urReq(flipkart_url)

# %%
data_flipkart = response.read()

# %%
beautified_html = bs(data_flipkart, "html.parser")

# %%
bigbox = beautified_html.find_all('div', {"class":"_1AtVbE col-12-12"})

# %%
product6 = "https://www.flipkart.com" + bigbox[6].div.div.div.a['href']

# %%
product6
# Out:
# 'https://www.flipkart.com/oneplus-11r-5g-galactic-silver-128-gb/p/itmd8344a066fd54?pid=MOBGN3C4MWPDUDYZ&lid=LSTMOBGN3C4MWPDUDYZR9CKY4&marketplace=FLIPKART&q=oneplus&store=search.flipkart.com&srno=s_1_21&otracker=search&fm=organic&iid=30ea2824-9370-4ce8-a121-5874ffe6f50b.MOBGN3C4MWPDUDYZ.SEARCH&ppt=None&ppn=None&ssid=og80ctey1s0000001702622979212&qH=43780d550576947f'

# %%
product66 = requests.get(product6)

# %%
product66
# Out:
# <Response [200]>

# %%
# Set the encoding for the response
product66.encoding = 'utf-8'

# Encode the text content
encoded_content = product66.text.encode('utf-8')
print(encoded_content)
# Out:
# b'<!doctype html><html lang="en"><head><link href="https://rukminim2.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.905c37.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.615ed9.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><meta name="robots" content="noodp"/><link rel="shortcut icon" href="https:///www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57" href="/apple-touch-icon-57x5
# ...

# %%
 product6_page = bs(product66.text, 'html.parser')

# %%
product6_page
# Out:
# <!DOCTYPE html>
# ...

# %%
all_review = product6_page.find_all('div', {"class":"_16PBlm"})

# %%
all_review
# Out:
# [<div class="_16PBlm"><div class="col"><div class="col _2wzgFH"><div class="row"><div class="_3LWZlK _1BLPMq">5<img class="_1wB99o" src="..."/></div><p class="_2-N8zT">Just wow!</p></div><div class="row"><div class="t-ZTKy"><div><div class="">Overall good phone<br/>If you want a all rounder phone just go for it</div><span class="_1H-bmy"><span>READ MORE</span></span></div></div></div><div class="_2nMSwX _3oLIki"><div class="_21YjFX _2A07HP" style="background-image:url(https://rukminim1.flixcart.com/blobio/124/124/imr/blobio-imr_58f52fba28704f7eabd5e84985c0125d.jpg?q=90), url(data:image/svg+xml;base64,...);width:62px;height:62px"></div><div class="_21YjFX _2A07HP" style="background-image:url(https://rukminim1.flixcart.com/blobio/124/124/imr/blobio-imr_9871745fecd649019607362a9b0a96e2.jpg?q=90), url(data:image/svg+xml;base64,...);width:62px;height:62px"></div></div><div class="row _3n8db9"><div class="row"><p class="_2sc7ZR _2V5EHH">Asad Ansari</p><svg class="_2a1p_T" height="14" viewb
# ...

# %%
len(all_review)
# Out:
# 11

# %%
all_review[5]
# Out:
# <div class="_16PBlm _3_IKGE"><div class="col"><div class="col _2wzgFH"><div class="row"><div class="_3LWZlK _1BLPMq">5<img class="_1wB99o" src="..."/></div><p class="_2-N8zT">Simply awesome</p></div><div class="row"><div class="t-ZTKy"><div><div class="">Just Awesome device. I try to explain the pros and cons of this device based on my experience<br/><br/><br/>Pros:<br/><br/>1) Super high resolution display, produces better colour and good views in direct sunlight. 5/5<br/>2) Battery 🔋 Just excellent. 100W fast charger is enough to charge the device 0 to 100% withing a half hour. I rated 5/5<br/>3) camera is decent, it's not disappoint you. I rated 4/5<br/>4) Performance like a beast. In my daily life experience I didn't notice any lag. But remember this is not a gaming Ph...</div><span class="_1BWGvX"><span>READ MORE</span></span></div></div></div><div class="_2nMSwX _3oLIki"><div class="_21YjFX _2A07HP" style="background-image:url(https://rukminim1.flixcart.com/blobio/124/124/imr/b
# ...

# %%
rating = all_review[5].div.div.div.div.text

# %%
rating
# Out:
# '5'

# %%
name = all_review[2].div.div.find_all('p', {"class":"_2sc7ZR _2V5EHH"})[0].text

# %%
name
# Out:
# 'AJAY SINGH'

# %%
comment_header = all_review[1].div.div.div.find_all('p', {"class":"_2-N8zT"})[0].text

# %%
comment_header
# Out:
# 'Classy product'

# %%
comment = all_review[0].div.div.find_all('div', {"class":""})[0].text

# %%
comment
# Out:
# 'Overall good phoneIf you want a all rounder phone just go for itREAD MORE'

# %%
product6_page
# Out:
# <!DOCTYPE html>
# ...

# %%
price = product6_page.find_all('div', {"class":"_30jeq3 _16Jk6d"})[0].text

# %%
price
# Out:
# '₹39,968'

# %%
product6_page.find_all('div', {"class":"_2418kt"})[0].text
# Out:
# '8 GB RAM | 128 GB ROM17.02 cm (6.7 inch) Display50MP Rear Camera5000 mAh Battery'

# %%
Date = all_review[0].div.div.find_all('p', {"class":"_2sc7ZR"})[1].text
# Out:
# '7 months ago'

# %%
for i in all_review:
    name = i.div.div.find_all('p', {"class":"_2sc7ZR _2V5EHH"})[0].text
    comment_header = i.div.div.div.find_all('p', {"class":"_2-N8zT"})[0].text
    comment = i.div.div.find_all('div', {"class":""})[0].text
    price = product6_page.find_all('div', {"class":"_30jeq3 _16Jk6d"})[0].text
    rating = i.div.div.div.div.text
    Date = i.div.div.find_all('p', {"class":"_2sc7ZR"})[1].text
    print(name, comment_header,comment, price, rating, Date)
# Out:
# Asad Ansari Just wow! Overall good phoneIf you want a all rounder phone just go for itREAD MORE ₹39,968 5 7 months ago
# Flipkart Customer Classy product So smooth display 😍😘READ MORE ₹39,968 5 7 months ago
# AJAY SINGH Wonderful AwesomeREAD MORE ₹39,968 5 8 months ago
# Mr mani Kandan Highly recommended Very good.. camera fantastic 😍READ MORE ₹39,968 5 7 months ago
# Ravi Rawat Fabulous! Overall performance is great but the battery drains faster I hope it will be betterREAD MORE ₹39,968 5 7 months ago
# ...

# %%
import mysql.connector as conn

mydb = conn.connect(host="localhost", user="root", passwd="*K37759@Others#")
cursor = mydb.cursor()

cursor.execute("CREATE DATABASE IF NOT EXISTS review")
cursor.execute("CREATE TABLE IF NOT EXISTS review.storeview (name VARCHAR(30), comment_header VARCHAR(90), comment VARCHAR(120), price VARCHAR(20), rating VARCHAR(10))")
