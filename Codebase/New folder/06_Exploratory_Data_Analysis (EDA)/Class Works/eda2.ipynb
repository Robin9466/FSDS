# %%
# Comment
# Observation

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv("student.csv")

# %%
data.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
data.tail()
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86

# %%
data.shape
# Out:
# (1000, 8)

# %%
data.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
data['gender'].dtypes=='object'
# Out:
# True

# %%
data.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
cat_col = [fea for fea in data.columns if data[fea].dtype == 'object']

# %%
num_col = [fea for fea in data.columns if data[fea].dtype != 'object']

# %%
data[num_col]
# Out:
#      math score  reading score  writing score
# 0            72             72             74
# 1            69             90             88
# 2            90             95             93
# 3            47             57             44
# 4            76             78             75
# ..          ...            ...            ...
# 995          88             99             95
# 996          62             55             55
# 997          59             71             65
# 998          68             78             77
# 999          77             86             86
#
# [1000 rows x 3 columns]

# %%
data[cat_col]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course
# 0                      none
# 1                 completed
# 2                      none
# ...

# %%
data.memory_usage()
# Out:
# Index                           128
# gender                         8000
# race/ethnicity                 8000
# parental level of education    8000
# lunch                          8000
# test preparation course        8000
# math score                     8000
# reading score                  8000
# writing score                  8000
# dtype: int64

# %%
data.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %% [markdown]
# Missing Values

# %%
data.isnull().sum().sum()
# Out:
# 0

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.nunique()
# Out:
# gender                          2
# race/ethnicity                  5
# parental level of education     6
# lunch                           2
# test preparation course         2
# math score                     81
# reading score                  72
# writing score                  77
# dtype: int64

# %%
data['gender'].unique()
# Out:
# array(['female', 'male'], dtype=object)

# %%
data.describe().T
# Out:
#                 count    mean        std   min    25%   50%   75%    max
# math score     1000.0  66.089  15.163080   0.0  57.00  66.0  77.0  100.0
# reading score  1000.0  69.169  14.600192  17.0  59.00  70.0  79.0  100.0
# writing score  1000.0  68.054  15.195657  10.0  57.75  69.0  79.0  100.0

# %%
data.corr()
# Out:
#                math score  reading score  writing score
# math score       1.000000       0.817580       0.802642
# reading score    0.817580       1.000000       0.954598
# writing score    0.802642       0.954598       1.000000

# %%
data.cov()
# Out:
#                math score  reading score  writing score
# math score     229.918998     180.998958     184.939133
# reading score  180.998958     213.165605     211.786661
# writing score  184.939133     211.786661     230.907992

# %%
data.skew()
# Out:
# math score      -0.278935
# reading score   -0.259105
# writing score   -0.289444
# dtype: float64

# %%
sns.distplot(data['math score'])
# Out:
# <Axes: xlabel='math score', ylabel='Density'>

# %%
data
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
data.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
data['Average'] = (data['math score']+data['writing score']+data['reading score'])/3

# %%
data.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score    Average
# 0                    none          72             72             74  72.666667
# 1               completed          69             90             88  82.333333
# 2                    none          90             95             93  92.666667
# 3                    none          47             57             44  49.333333
# 4                    none          76             78             75  76.333333

# %%
 data.groupby('gender').mean()
# Out:
#         math score  reading score  writing score    Average
# gender
# female   63.633205      72.608108      72.467181  69.569498
# male     68.728216      65.473029      63.311203  65.837483

# %%
 data.groupby('gender').count()
# Out:
#         race/ethnicity  parental level of education  lunch  \
# gender
# female             518                          518    518
# male               482                          482    482
#
#         test preparation course  math score  reading score  writing score  \
# gender
# female                      518         518            518            518
# male                        482         482            482            482
#
#         Average
# gender
# female      518
# male        482

# %%
# Question: You have to find out no of student whoever is having less than 30 marks math

# %%
data[data['math score']<30].count()
# Out:
# gender                         14
# race/ethnicity                 14
# parental level of education    14
# lunch                          14
# test preparation course        14
# math score                     14
# reading score                  14
# writing score                  14
# Average                        14
# dtype: int64

# %%
p value
if p > 0.05
# Out:
#   File "<ipython-input-67-300665d6f1b9>", line 1
#     p value
#       ^
# SyntaxError: invalid syntax

# %%
data.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score', 'Average'],
#       dtype='object')

# %%
data_num = data[num_col]

# %%
data_num.head()
# Out:
#    math score  reading score  writing score
# 0          72             72             74
# 1          69             90             88
# 2          90             95             93
# 3          47             57             44
# 4          76             78             75

# %%
from scipy.stats import normaltest

# %%
normaltest(data_num['math score'])[1]*100
# Out:
# 0.04508029386993784

# %%
# if p > 0.05, then my data will be noramally distributed, if p < 0.05, data will be non normally distributed.

# %%
# Outlier

# %%
sns.boxplot(data=data['math score'])
# Out:
# <Axes: >

# %%
sns.boxplot(data=data['reading score'])
# Out:
# <Axes: >

# %%
sns.boxplot(data=data['writing score'])
# Out:
# <Axes: >

# %%
q1 = data['math score'].quantile(0.25)

# %%
q3 = data['math score'].quantile(0.75)

# %%
IQR = q3 - q1

# %%
upper_limit = q3 + (1.5*IQR)

# %%
upper_limit
# Out:
# 107.0

# %%
lower_limit = q1 - (1.5*IQR)

# %%
lower_limit
# Out:
# 27.0

# %%
data[data['math score']<lower_limit]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 17   female        group B            some high school  free/reduced
# 59   female        group C            some high school  free/reduced
# 145  female        group C                some college  free/reduced
# 338  female        group B            some high school  free/reduced
# 466  female        group D          associate's degree  free/reduced
# 787  female        group B                some college      standard
# 842  female        group B                 high school  free/reduced
# 980  female        group B                 high school  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 17                     none          18             32             28
# 59                     none           0             17             10
# 145                    none          22             39             33
# ...

# %%
data[data['math score']>upper_limit]
# Out:
# Empty DataFrame
# Columns: [gender, race/ethnicity, parental level of education, lunch, test preparation course, math score, reading score, writing score, Average]
# Index: []

# %%
data['math score'].min()
# Out:
# 0

# %%
data['math score'].max()
# Out:
# 100

# %%
data['math score'].unique()
# Out:
# array([ 72,  69,  90,  47,  76,  71,  88,  40,  64,  38,  58,  65,  78,
#         50,  18,  46,  54,  66,  44,  74,  73,  67,  70,  62,  63,  56,
#         97,  81,  75,  57,  55,  53,  59,  82,  77,  33,  52,   0,  79,
#         39,  45,  60,  61,  41,  49,  30,  80,  42,  27,  43,  68,  85,
#         98,  87,  51,  99,  84,  91,  83,  89,  22, 100,  96,  94,  48,
#         35,  34,  86,  92,  37,  28,  24,  26,  95,  36,  29,  32,  93,
#         19,  23,   8])

# %%
data['math score'].quantile(1.0)
# Out:
# 100.0

# %%
data_num.columns
# Out:
# Index(['math score', 'reading score', 'writing score'], dtype='object')

# %%
def outlier_threshold(df, variable):
    q1 = df[variable].quantile(0.25)
    q3 = df[variable].quantile(0.75)
    iqr = q3 - q1
    upper_limit = q3 + (1.5*iqr)
    lower_limit = q1 + (1.5*iqr)
    return lower_limit, upper_limit

# %%
for variable in data_num.columns:
    lower_limit, upper_limit = outlier_threshold(data_num, variable)

# %%
def replace_with_threshold(data,numeric_col):
    for variable in data_num.columns:
        lower_limit, upper_limit = outlier_threshold(data_num, variable)
        data.loc[data[variable]<lower_limit,variable]=lower_limit
        data.loc[data[variable]<upper_limit,variable]=upper_limit

# %%
replace_with_threshold(data_num, data_num.columns)

# %% [markdown]
# Graph analysis

# %%
data
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
data['gender'] = data['gender'].astype('category')

# %%
sns.countplot(data['gender'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-127-da2e2a36e95b> in <cell line: 1>()
# ----> 1 sns.countplot(data['gender'])
#
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, ax, **kwargs)
#    2941         raise ValueError("Cannot pass values for both `x` and `y`")
#    2942
# -> 2943     plotter = _CountPlotter(
#    2944         x, y, hue, data, order, hue_order,
#    2945         estimator, errorbar, n_boot, units, seed,
#
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py in __init__(self, x, y, hue, data, order, hue_order, estimator, errorbar, n_boot, units, seed, orient, color, palette, saturation, width, errcolor, errwidth, capsize, dodge)
#    1528                  errcolor, errwidth, capsize, dodge):
# ...

# %%
print(data['gender'].unique())
# Out:
# ['female', 'male']
# Categories (2, object): ['female', 'male']

# %%
data['gender'] = data['gender'].astype('category')

# %%
sns.countplot(data['gender'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-134-da2e2a36e95b> in <cell line: 1>()
# ----> 1 sns.countplot(data['gender'])
#
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, ax, **kwargs)
#    2941         raise ValueError("Cannot pass values for both `x` and `y`")
#    2942
# -> 2943     plotter = _CountPlotter(
#    2944         x, y, hue, data, order, hue_order,
#    2945         estimator, errorbar, n_boot, units, seed,
#
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py in __init__(self, x, y, hue, data, order, hue_order, estimator, errorbar, n_boot, units, seed, orient, color, palette, saturation, width, errcolor, errwidth, capsize, dodge)
#    1528                  errcolor, errwidth, capsize, dodge):
# ...

# %%
sns.countplot(x='gender', data=data)
# Out:
# <Axes: xlabel='gender', ylabel='count'>

# %%
data
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
sns.countplot(x='race/ethnicity', data=data)
# Out:
# <Axes: xlabel='race/ethnicity', ylabel='count'>

# %%
data
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
df = data.groupby('gender').mean()

# %%
df['Average'][0]
# Out:
# 69.56949806949807

# %%
df['Average'][1]
# Out:
# 65.8374827109267

# %%
df['math score'][0]
# Out:
# 63.633204633204635

# %%
df['math score'][1]
# Out:
# 68.72821576763485

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(10, 10))

X = ['Total avg', 'math avg']
female_scores = [df['Average'][0], df['math score'][0]]
male_scores = [df['Average'][1], df['math score'][1]]

X_axis = np.arange(len(X))

# Use correct function names and fix the bar plot parameters
plt.bar(X_axis - 0.2, male_scores, 0.4, label='male')
plt.bar(X_axis + 0.2, female_scores, 0.4, label='female')

plt.xticks(X_axis, X)
plt.ylabel("marks")  # Fix the typo in ylabel
plt.title("Total avg vs math avg", fontweight='bold')  # Fix the typo in title
plt.legend()
plt.show()

# %%
data_num.corr()
# Out:
#                math score  reading score  writing score
# math score       1.000000       0.817580       0.802642
# reading score    0.817580       1.000000       0.954598
# writing score    0.802642       0.954598       1.000000

# %%
sns.heatmap(data_num.corr()
.corr(), annot=True,cmap='icefire',linewidths=0.3)
fig=plt.gcf()
fig.set_size_inches(10,10)
plt.title("corr between variable", color='black', size=15)
plt.show()

# %%
sns.pairplot(data_num)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.violinplot(x=data_num['math score'], y=data_num['writing score'], hue=None)
plt.xlabel('Math Score')
plt.ylabel('Writing Score')
plt.title('Violin Plot of Writing Score vs Math Score')
plt.show()

# %%
sns.violinplot(data=data_num)
# Out:
# <Axes: >
