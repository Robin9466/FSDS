# %%
True/False
n=5+9j
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-7-24a47ad29f85> in <cell line: 1>()
# ----> 1 True/False
#       2 n=5+9j
#
# ZeroDivisionError: division by zero

# %%
n = 7+5j

type(n)
# Out:
# complex

# %%
n=5+7j

# %%
type(n)
# Out:
# complex

# %%
n+n
# Out:
# (14+10j)

# %%
n
# Out:
# (7+5j)

# %%
n.real
# Out:
# 7.0

# %%
n.conjugate
# Out:
# <function complex.conjugate()>

# %%
n.imag
# Out:
# 5.0

# %%
b= " This is Python's class"

# %%
type(b)
# Out:
# str

# %%
l=[3,4,5,6,"sudh,True",5+1j,345,456]

# %%
type(l)
# Out:
# list

# %%
l[1]
# Out:
# 4

# %%
t=(325,444,446,84,545,"454545","h")

# %%
type(t)
# Out:
# tuple

# %%
d={'a' : "sfsf", "b",  d: "ssdg", "c" : 5545}
# Out:
#   File "<ipython-input-34-e103d13f7935>", line 1
#     d={'a' : "sfsf", "b",  d: "ssdg", "c" : 5545}
#                        ^
# SyntaxError: ':' expected after dictionary key

# %%
type(d)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-c0f6703a6fe5> in <cell line: 1>()
# ----> 1 type(d)
#
# NameError: name 'd' is not defined
