# %% [markdown]
# ### **Phase 2: Core Concepts**
#
# This phase dives deeper into the core mathematical concepts essential for advanced data science techniques and their practical applications.
#
# ---
#
# ## **1. Linear Algebra**
#
# ### **Definition**:
# Linear Algebra is the branch of mathematics that deals with vectors, matrices, and their transformations. It is foundational for handling multidimensional data and computations in machine learning and data science.
#
# ---
#
# ### **Topics Covered**:
#
# #### **Vectors, Matrices, and Matrix Operations**
# - **Meaning**:
# Vectors represent quantities with both magnitude and direction (e.g., `[1, 2, 3]`). Matrices are 2D arrays of numbers used to store and manipulate data efficiently. Operations like addition, multiplication, and transpose are essential for data manipulation.
#
# - **Reasoning**:
# Used in data transformation, linear regression, and neural networks.
# For example: Converting features into mathematical models.
#
# - **Practical Application**:
#    - Representing datasets as matrices (rows = samples, columns = features).
#    - Transforming data with matrix multiplication (e.g., scaling features).
#
# #### **Eigenvalues and Eigenvectors**
# - **Meaning**:
# Eigenvalues measure the "stretch" of a transformation, while eigenvectors indicate the direction.
#
# - **Reasoning**:
# These are critical in reducing dimensionality (e.g., Principal Component Analysis).
#
# - **Practical Application**:
#    - Identifying important features in datasets.
#    - Reducing noise in large datasets for efficient computation.
#
# ---
#
# ### **Guided Exercise: Vectors and Matrices**
#
# **Problem**: Represent a dataset of student scores (`Math`, `Science`, `English`) as a matrix and calculate the **mean score** per subject using NumPy.
#
# **Solution (ChatGPT)**:
#
# ```python
# import numpy as np
#
# # Dataset as a matrix
# scores = np.array([
#     [85, 90, 78],  # Student 1
#     [88, 94, 80],  # Student 2
#     [84, 89, 76],  # Student 3
# ])
#
# # Calculate mean score per subject
# mean_scores = np.mean(scores, axis=0)
# print(f"Mean scores (Math, Science, English): {mean_scores}")
# ```
#
# ---
#
# **Your Exercise**:
# 1. Add a new subject, "History," to the dataset and recalculate the mean scores for all subjects.
#
# ---
#
# ### **Mini-Project: PCA (Principal Component Analysis)**
#
# **Guided Mini-Project**:
# 1. Use a dataset with features like height, weight, and age.
# 2. Perform PCA to reduce the dataset to 2 dimensions.
#
# **Dataset**:
# ```csv
# Height,Weight,Age
# 170,70,25
# 160,65,30
# 180,75,35
# ```
#
# **Code**:
#
# ```python
# from sklearn.decomposition import PCA
# import pandas as pd
#
# # Create the dataset
# data = pd.DataFrame({
#     'Height': [170, 160, 180],
#     'Weight': [70, 65, 75],
#     'Age': [25, 30, 35]
# })
#
# # Perform PCA
# pca = PCA(n_components=2)
# reduced_data = pca.fit_transform(data)
#
# print("Reduced Data:\n", reduced_data)
# ```
#
# **Your Mini-Project**:
# 1. Use a dataset with 4 features (e.g., `Income`, `Expenses`, `Savings`, `Debt`) and reduce it to 2 dimensions using PCA.
#
# ---
#
# ## **2. Statistics and Probability (Advanced)**
#
# ### **Topics Covered**:
#
# #### **Probability Distributions**
# - **Meaning**:
# Probability distributions show how likely outcomes are. Examples: Normal, Poisson, Binomial.
#
# - **Reasoning**:
# Helps model real-world phenomena like customer purchases or stock price trends.
#
# - **Practical Application**:
#    - Modeling sales data with normal distribution.
#    - Predicting the likelihood of specific events like product defects.
#
# #### **Hypothesis Testing and P-Values**
# - **Meaning**:
# Hypothesis testing determines if data supports a particular claim, and p-values measure the significance.
#
# - **Reasoning**:
# Used for validating models and experiments in data science.
#
# - **Practical Application**:
#    - Checking if a marketing campaign increases sales.
#    - Evaluating if two datasets come from the same distribution.
#
# ---
#
# ### **Guided Exercise: Normal Distribution**
#
# **Problem**: Generate a normal distribution of **customer purchases** with a mean of `50` and standard deviation of `10`.
#
# **Solution (ChatGPT)**:
#
# ```python
# import numpy as np
# import matplotlib.pyplot as plt
#
# # Generate normal distribution
# data = np.random.normal(loc=50, scale=10, size=1000)
#
# # Plot the distribution
# plt.hist(data, bins=30, density=True)
# plt.title("Normal Distribution of Customer Purchases")
# plt.xlabel("Number of Purchases")
# plt.ylabel("Density")
# plt.show()
# ```
#
# ---
#
# **Your Exercise**:
# 1. Generate a Poisson distribution with a mean of `5` and plot it.
#
# ---
#
# ## **3. Calculus**
#
# ### **Definition**:
# Calculus involves the study of change (differentiation) and accumulation (integration). It’s used in optimization and modeling dynamic systems in data science.
#
# ---
#
# ### **Topics Covered**:
#
# #### **Differentiation**
# - **Meaning**:
# Measures the rate of change of a function.
#
# - **Reasoning**:
# Used for optimization problems in machine learning (e.g., gradient descent).
#
# - **Practical Application**:
#    - Optimizing cost functions in regression models.
#    - Identifying trends and patterns in data.
#
# #### **Integration**
# - **Meaning**:
# Calculates the cumulative value of a function over an interval.
#
# - **Reasoning**:
# Used to calculate areas under curves, important for model evaluation.
#
# - **Practical Application**:
#    - Calculating total revenue over time.
#    - Evaluating the area under ROC curves in classification problems.
#
# ---
#
# ### **Guided Exercise: Gradient Descent**
#
# **Problem**: Write a Python function to perform a single step of gradient descent on a simple cost function, \( f(x) = x^2 \).
#
# **Solution (ChatGPT)**:
#
# ```python
# def gradient_descent(x, learning_rate):
#     gradient = 2 * x  # Derivative of x^2 is 2x
#     new_x = x - learning_rate * gradient
#     return new_x
#
# # Perform a step of gradient descent
# x_initial = 10
# learning_rate = 0.1
# new_x = gradient_descent(x_initial, learning_rate)
# print(f"Updated x after one step: {new_x}")
# ```
#
# ---
#
# **Your Exercise**:
# 1. Perform multiple steps of gradient descent starting from `x = 20` with a learning rate of `0.05`.
#
# ---
#
# ### **Mini-Project: Stock Price Prediction**
#
# **Guided Mini-Project**:
# 1. Use a dataset of stock prices.
# 2. Fit a normal distribution to the daily returns and predict future trends.
#
# **Code**:
#
# ```python
# # Simulated stock returns
# returns = np.random.normal(0.001, 0.02, 1000)
#
# # Plot the returns
# plt.hist(returns, bins=50, density=True)
# plt.title("Normal Distribution of Stock Returns")
# plt.xlabel("Daily Return")
# plt.ylabel("Density")
# plt.show()
# ```
#
# **Your Mini-Project**:
# 1. Use historical stock prices to calculate daily returns and plot the distribution.
#
# ---
#
# This phase combines **concepts**, **reasoning**, **practical applications**, and **hands-on coding** for a comprehensive understanding of advanced topics. Let me know if you want to dive into any specific part in more detail!

# %% [markdown]
# Guided Exercise: Vectors and Matrices
# Problem: Represent a dataset of student scores (Math, Science, English) as a matrix and calculate the mean score per subject using NumPy.
#
# Solution (ChatGPT)

# %%
import numpy as np

# Dataset as a matrix
scores = np.array([
    [85, 90, 78], # Student 1
    [88, 94, 80], # Student 2
    [84, 89, 76], # Student 3
])

# Calculate mean score per subject
mean_scores = np.mean(scores, axis=0)
print(f"Mean scores (Math, Science, English): {mean_scores}")
# Out:
# Mean scores (Math, Science, English): [85.66666667 91.         78.        ]

# %% [markdown]
# Your Exercise:
#
# Add a new subject, "History," to the dataset and recalculate the mean scores for all subjects.

# %%
history_column = np.array([95, 97, 78])

# Reshape the new column to a column vector
history_column = history_column.reshape(-1, 1)

# Append the new column
new_scores = np.append(scores, history_column, axis=1)

# Recalculate the mean scores for all subjects across all students
mean_scores1 = np.mean(new_scores, axis=0)
print(f"Mean scores (Math, Science, English, History): {mean_scores1}")
# Out:
# Mean scores (Math, Science, English, History): [85.66666667 91.         78.         90.        ]

# %% [markdown]
# Mini-Project: PCA (Principal Component Analysis)
# Guided Mini-Project:
#
# Use a dataset with features like height, weight, and age.
# Perform PCA to reduce the dataset to 2 dimensions.
#
# Height,Weight,Age
# 170,70,25
# 160,65,30
# 180,75,35

# %%
from sklearn.decomposition import PCA
import pandas as pd

# Create the dataset
data = pd.DataFrame({
      'Height': [170, 160, 180],
    'Weight': [70, 65, 75],
    'Age': [25, 30, 35]
})

# Perform PCA
pca = PCA(n_components=2)
reduced_data = pca.fit_transform(data)

print("Reduced Data:\n", reduced_data)
# Out:
# Reduced Data:
#  [[ -1.26059727  -4.8384806 ]
#  [-10.81917153   2.8187812 ]
#  [ 12.0797688    2.0196994 ]]

# %% [markdown]
# Your Mini-Project:
#
# Use a dataset with 4 features (e.g., Income, Expenses, Savings, Debt) and reduce it to 2 dimensions using PCA.
# 00	1800

# %%
from sklearn.decomposition import PCA
import pandas as pd

# Create the dataset
data = {
    "Income": [5000, 7000, 8000, 6000, 7500, 9000, 10000, 11000, 9500, 10500],
    "Expenses": [2000, 2500, 3000, 2200, 2700, 3300, 4000, 4200, 3600, 3900],
    "Savings": [1500, 2000, 2500, 1800, 2100, 2800, 3500, 3800, 3000, 3200],
    "Debt": [1000, 1500, 1200, 800, 1300, 2000, 2500, 2200, 1600, 1800]
}

# Convert dictionary data to DataFrame
df = pd.DataFrame(data)

# Perform PCA
pca = PCA(n_components=2)
reduced_data = pca.fit_transform(df)

print("Reduced Data:\n", reduced_data)

import matplotlib.pyplot as plt

plt.scatter(reduced_data[:, 0], reduced_data[:, 1])
plt.title("PCA Reduced Data")
plt.xlabel("Principal Component 1")
plt.ylabel("Principal Component 2")
plt.show()
# Out:
# Reduced Data:
#  [[-3748.64567922   233.27071271]
#  [-1596.50817239   178.85721458]
#  [ -466.4530297   -279.22311921]
#  [-2764.58489252  -200.7769411 ]
#  [-1107.53704057  -131.28863682]
#  [  754.67703123   212.66676933]
#  [ 2180.17491684   547.06405206]
#  [ 3143.89266873    21.30861725]
#  [ 1269.31132572  -251.48695976]
#  [ 2335.67287187  -330.39170903]]

# %% [markdown]
# Guided Exercise: Normal Distribution
# Problem: Generate a normal distribution of customer purchases with a mean of 50 and standard deviation of 10.
#
# Solution (ChatGPT):

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate normal distribution
# Use np.random.normal instead of np.random
data = np.random.normal(loc=50, scale=10, size=1000)

# Plot the distribution
plt.hist(data, bins=30, density=True)
plt.title("Normal Distribution of Customer Purchases")
plt.xlabel("Number of Purchases")
plt.ylabel("Density")
plt.show()

# %% [markdown]
# Generate a Poisson distribution with a mean of 5 and plot it.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Parameters for Poisson distribution
mean = 5

# Generate Poisson distribution data
data = np.random.poisson(mean, 1000)

# Plot the distribution
plt.hist(data, bins=range(0, max(data)+2), density=True, alpha=0.75, color='blue', edgecolor='black')
plt.title('Poisson Distribution (mean = 5)')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
